# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("/content/Unemployment_Rate_upto_11_2020.csv")

# Show First Rows
print(df.head())

# Dataset Information
print(df.info())

# Check Missing Values
print(df.isnull().sum())

# Remove Missing Values
df.dropna(inplace=True)

# Rename Columns
df.columns = [
    'States',
    'Date',
    'Frequency',
    'Estimated Unemployment Rate',
    'Estimated Employed',
    'Estimated Labour Participation Rate',
    'Region',
    'Longitude',
    'Latitude'
]

# Convert Date Column
df['Date'] = pd.to_datetime(df['Date'], format="%d-%m-%Y")

# Display Clean Data
print(df.head())

# Average Unemployment Rate
avg_rate = df['Estimated Unemployment Rate'].mean()

print("Average Unemployment Rate:", avg_rate)

# Plot Unemployment Rate
plt.figure(figsize=(12,6))

plt.plot(
    df['Date'],
    df['Estimated Unemployment Rate']
)

plt.xlabel("Date")
plt.ylabel("Unemployment Rate")
plt.title("Unemployment Rate Over Time")

plt.xticks(rotation=45)

plt.show()

# Top 10 States with Highest Unemployment
top_states = df.groupby('States')[
    'Estimated Unemployment Rate'
].mean().sort_values(ascending=False).head(10)

print(top_states)

# Bar Graph
plt.figure(figsize=(12,6))

top_states.plot(kind='bar')

plt.xlabel("States")
plt.ylabel("Average Unemployment Rate")
plt.title("Top 10 States by Unemployment Rate")

plt.show()
# Out:
#            States        Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh  01-01-2020   Monthly                         8.93
# 1       Telangana  01-01-2020   Monthly                        16.23
# 2       Karnataka  01-01-2020   Monthly                         5.20
# 3      Tamil Nadu  01-01-2020   Monthly                        12.80
# 4          Kerala  01-01-2020   Monthly                        15.24
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0             7454271                                53.19  South    83.0230
# 1             7550699                                35.79  South    76.1165
# 2             1234197                                38.40  South    73.1533
# 3             1415415                                55.93  South    73.6724
# 4             6346634                                40.34  South    81.8733
#
#    Latitude
# 0   16.9357
# 1   14.9320
# 2   27.1957
# 3   18.0056
# 4   16.6585
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   States                               96 non-null     object
#  1   Date                                 96 non-null     object
#  2   Frequency                            96 non-null     object
#  3   Estimated Unemployment Rate          96 non-null     float64
#  4   Estimated Employed                   96 non-null     int64
#  5   Estimated Labour Participation Rate  96 non-null     float64
#  6   Region                               96 non-null     object
#  7   Longitude                            96 non-null     float64
#  8   Latitude                             96 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 6.9+ KB
# None
# States                                 0
# Date                                   0
# Frequency                              0
# Estimated Unemployment Rate            0
# Estimated Employed                     0
# Estimated Labour Participation Rate    0
# Region                                 0
# Longitude                              0
# Latitude                               0
# dtype: int64
#            States       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2020-01-01   Monthly                         8.93
# 1       Telangana 2020-01-01   Monthly                        16.23
# 2       Karnataka 2020-01-01   Monthly                         5.20
# 3      Tamil Nadu 2020-01-01   Monthly                        12.80
# 4          Kerala 2020-01-01   Monthly                        15.24
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0             7454271                                53.19  South    83.0230
# 1             7550699                                35.79  South    76.1165
# 2             1234197                                38.40  South    73.1533
# 3             1415415                                55.93  South    73.6724
# 4             6346634                                40.34  South    81.8733
#
#    Latitude
# 0   16.9357
# 1   14.9320
# 2   27.1957
# 3   18.0056
# 4   16.6585
# Average Unemployment Rate: 11.236770833333333
# States
# Maharashtra       12.907500
# Tamil Nadu        12.219167
# Karnataka         11.960833
# Delhi             11.204167
# Telangana         10.913333
# Kerala            10.815833
# Andhra Pradesh    10.326667
# Gujarat            9.546667
# Name: Estimated Unemployment Rate, dtype: float64
